# %% [markdown]
# # Pneumothorax demo
#
# This demo exists to show some additional functionality of misas and to demonstrate that it is applicable to non MRI data. In this case chest X-rays.
# This demo is a variation of the one shown in the fastai 2 docs where the dataset is used for classification. We use it to do segmentation.
#
# > Warning:
# We will massively overfit the data just to showcase some functionality. The resulting model is not suitable for productive usage at all.

# %%
#hide
#skip
! [[ -e /content ]] && git clone https://github.com/chfc-cmi/misas && cd misas && pip install .
import os
if os.path.isdir('/content/misas'):
    os.chdir('/content/misas')

# %%
#hide
import warnings
warnings.filterwarnings('ignore')

# %%
from fastai.vision.all import *
from fastai.medical.imaging import *
import torchvision
import torchvision.transforms as t

# %%
pneumothorax_source = untar_data(URLs.SIIM_SMALL)

# %%
pneumothorax_source.ls()
# Out:
# (#2) [Path('/tmp/fastai/siim_small/train'),Path('/tmp/fastai/siim_small/labels.csv')]

# %%
items = get_dicom_files(pneumothorax_source/f"train/")

# %%
df = pd.read_csv(pneumothorax_source/f"labels.csv")
df.head()
# Out:
#                                file            label
# 0  train/No Pneumothorax/000000.dcm  No Pneumothorax
# 1     train/Pneumothorax/000001.dcm     Pneumothorax
# 2  train/No Pneumothorax/000002.dcm  No Pneumothorax
# 3     train/Pneumothorax/000003.dcm     Pneumothorax
# 4     train/Pneumothorax/000004.dcm     Pneumothorax

# %%
df_pneumo = df[df['label']=='Pneumothorax']

# %%
pneumothorax = DataBlock(blocks=(ImageBlock(cls=PILDicom), MaskBlock(codes=['bg','pneumo'])),
                   get_x=lambda x:pneumothorax_source/f"{x[0]}",
                   get_y=lambda x:'example/siim/'+Path(x[0]).stem+'.png',
                   batch_tfms=aug_transforms(do_flip=False,p_affine=0,p_lighting=0,size=224))

dls = pneumothorax.dataloaders(df_pneumo.values, num_workers=0, bs=16)

# %%
dls.show_batch(max_n=16, vmin=0)

# %%
# just for testing - you can skip this when running interactively
learn = unet_learner(dls, resnet34)

# %%
learn.fine_tune(1)

# %%
#slow
# this is skipped when testing, instead a single epoch is done (not sufficient for overfitting)
learn = unet_learner(dls, resnet34)
learn.fine_tune(8)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.664146</td>
#       <td>0.137895</td>
#       <td>03:59</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.230625</td>
#       <td>0.232373</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.177801</td>
#       <td>0.122334</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.150451</td>
#       <td>0.093263</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.135144</td>
#       <td>0.091176</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.124003</td>
#       <td>0.103092</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.113540</td>
#       <td>0.084442</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.105772</td>
#       <td>0.109347</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.097995</td>
#       <td>0.101802</td>
#       <td>01:01</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.show_results(ds_idx=0,max_n=9,vmin=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
preds = learn.get_preds(ds_idx=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
plt.imshow(preds[1][2])

# %%
preds[0].argmax(dim=1).sum()
#plt.imshow(preds[0].argmax(dim=1)[0])
# Out:
# TensorBase(0)

# %%
#slow
learn.fine_tune(8)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.099294</td>
#       <td>12.696006</td>
#       <td>00:54</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.627802</td>
#       <td>0.293466</td>
#       <td>05:32</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.328314</td>
#       <td>0.179201</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.893322</td>
#       <td>0.086296</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.668462</td>
#       <td>0.083679</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.532176</td>
#       <td>0.069346</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.440292</td>
#       <td>0.076410</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.373660</td>
#       <td>0.070986</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.323529</td>
#       <td>0.074891</td>
#       <td>01:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
preds = learn.get_preds(ds_idx=0)
preds[0].argmax(dim=1).sum()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# TensorBase(0)

# %%
fig, axs = plt.subplots(5,2,figsize=(8,16))
for i in range(5):
    axs[i,0].imshow(preds[1][i])
    axs[i,1].imshow(preds[0][i][1])
    print(preds[0][i][1].max())
# Out:
# TensorBase(0.3764)
# TensorBase(0.2290)
# TensorBase(0.3339)
# TensorBase(0.3660)
# TensorBase(0.3362)

# %%
#slow
learn.fit_one_cycle(8)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.042251</td>
#       <td>0.127308</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.046954</td>
#       <td>0.069913</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.044693</td>
#       <td>0.071491</td>
#       <td>01:01</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.042069</td>
#       <td>0.168886</td>
#       <td>01:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.039679</td>
#       <td>0.101072</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.037447</td>
#       <td>0.079553</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.035225</td>
#       <td>0.099245</td>
#       <td>01:00</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.033133</td>
#       <td>0.102243</td>
#       <td>01:00</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds = learn.get_preds(ds_idx=0)
preds[0].argmax(dim=1).sum()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# TensorBase(13130)

# %%
#slow
learn.fit_one_cycle(20)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.022108</td>
#       <td>0.109468</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.021619</td>
#       <td>0.129985</td>
#       <td>00:59</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.021495</td>
#       <td>0.112901</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.020009</td>
#       <td>0.204513</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.019055</td>
#       <td>0.190159</td>
#       <td>00:58</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.019495</td>
#       <td>0.125951</td>
#       <td>01:04</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.020086</td>
#       <td>0.063032</td>
#       <td>00:57</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.020458</td>
#       <td>0.236187</td>
#       <td>01:02</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.020296</td>
#       <td>0.103601</td>
#       <td>02:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.019842</td>
#       <td>0.159561</td>
#       <td>01:10</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.019106</td>
#       <td>0.113190</td>
#       <td>01:28</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.018411</td>
#       <td>0.140291</td>
#       <td>01:08</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.017572</td>
#       <td>0.190142</td>
#       <td>01:47</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.016744</td>
#       <td>0.169453</td>
#       <td>02:15</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.015994</td>
#       <td>0.178823</td>
#       <td>02:10</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.015257</td>
#       <td>0.174640</td>
#       <td>02:42</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.014598</td>
#       <td>0.165832</td>
#       <td>02:36</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.013992</td>
#       <td>0.162043</td>
#       <td>02:17</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.013413</td>
#       <td>0.161409</td>
#       <td>02:23</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.012901</td>
#       <td>0.161526</td>
#       <td>02:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
preds = learn.get_preds(ds_idx=0)
preds[0].argmax(dim=1).sum()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# TensorBase(48229)

# %%
fig, axs = plt.subplots(5,3,figsize=(12,16))
for i in range(5):
    axs[i,0].imshow(preds[1][i])
    axs[i,1].imshow(preds[0][i][1])
    axs[i,2].imshow(preds[0].argmax(dim=1)[i])
    print(preds[0][i][1].max())
# Out:
# TensorBase(1.0000)
# TensorBase(0.9965)
# TensorBase(0.9965)
# TensorBase(0.9959)
# TensorBase(0.9508)

# %%
learn.save('pneumothorx')#learn.export(os.path.abspath('./my_export.pkl'))
# Out:
# Path('models/pneumothorx.pth')

# %% [markdown]
# ### We managed to overfit

# %%
learn.load ('pneumothorx')

# %%
from misas.core import *
from fastai.vision.all import * #open_mask, Image, ImageSegment
import pydicom

# %%
def read_dcm(file):
    ds = pydicom.dcmread(file)
    img = Tensor(ds.pixel_array.astype(np.int16))
    img = img/img.max()
    transform = t.ToPILImage()
    img = transform (torch.stack([img, img, img]))
    #img = Image.fromarray(np.array(torch.stack([img, img, img])))
    #img = Image(img.unsqueeze(0))
    #img = img.flip_lr()
    #img= img.rotate(90)
    return img

# %%
#def read_dcm(fname):
#    dcm = fname.dcmread()
#    pixels = dcm.pixels.unsqueeze(0)
#    pixels = torch.cat((pixels,pixels,pixels), dim=0)
#    return Image(pixels/255)

# %%
learn.predict(learn.dls.train_ds.items[1])[0].show(vmin=0)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <AxesSubplot:>

# %%
fname = df_pneumo.iloc[3]['file']
img = lambda: read_dcm(pneumothorax_source/fname)
trueMask = lambda: Image.open('example/siim/'+Path(fname).stem+'.png') #open_mask('example/siim/'+Path(fname).stem+'.png')

# %%
dcm = img()

# %%
dcm
#to_image(dcm.data)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x1024 at 0x7FB9805C5460>

# %%
pred = learn.predict(PILDicom(dcm))[1] #plt.imshow(learn.predict(PILDicom(dcm))[1]) #plt.imshow(learn.predict(PILDicom(to_image(dcm.data)))[1])
print(type(pred))
print(pred.shape)
plt.imshow(pred)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <class 'fastai.torch_core.TensorBase'>
# torch.Size([224, 224])

# %%
class Fastai2_wrapper:
    def __init__(self, model):
        self.model = model
        self.model.cbs = L([])
    
    def imageToPILDicom(self, image):
        return PILDicom(image)
    
    def prepareSize(self, imageOrMask):
        return imageOrMask.resize((224,224))
    
    def predict(self, image):
        image = self.imageToPILDicom(image)
        #image = (np.array(image)) 
        pred = self.model.predict(image)[0]#(in_image)
        #return Image.fromarray(np.array(ImageSegment(pred[1].unsqueeze(0)),))
        #return Image.fromarray(np.array((pred[1].unsqueeze(0))).astype(np.uint8))
        return Image.fromarray(np.array(pred).astype(np.uint8)) #Image.fromarray(np.array((pred)).astype(np.uint8))

# %%
model = Fastai2_wrapper(learn)

# %%
#learn.cbs = L(learn.cbs)#
#learn.cbs.sorted()

# %%
plt.imshow(model.predict(img()))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [71], in <cell line: 1>()
# ----> 1 plt.imshow(model.predict(img()))
#
# Input In [68], in Fastai2_wrapper.predict(self, image)
#      13 image = self.imageToPILDicom(image)
#      14 #image = (np.array(image))
# ---> 15 pred = self.model.predict(image)[0]#(in_image)
#      16 #return Image.fromarray(np.array(ImageSegment(pred[1].unsqueeze(0)),))
#      17 #return Image.fromarray(np.array((pred[1].unsqueeze(0))).astype(np.uint8))
#      18 return Image.fromarray(np.array(pred).astype(np.uint8))
#
# File ~/miniconda3/lib/python3.9/site-packages/fastai/learner.py:269, in Learner.predict(self, item, rm_type_tfms, with_input)
#     267 def predict(self, item, rm_type_tfms=None, with_input=False):
#     268     dl = self.dls.test_dl([item], rm_type_tfms=rm_type_tfms, num_workers=0)
# --> 269     inp,preds,_,dec_preds = self.get_preds(dl=dl, with_input=True, with_decoded=True)
#     270     i = getattr(self.dls, 'n_inp', -1)
#     271     inp = (inp,) if i==1 else tuplify(inp)
#
# File ~/miniconda3/lib/python3.9/site-packages/fastai/learner.py:255, in Learner.get_preds(self, ds_idx, dl, with_input, with_decoded, with_loss, act, inner, reorder, cbs, **kwargs)
#     253 ctx_mgrs = self.validation_context(cbs=L(cbs)+[cb], inner=inner)
#     254 if with_loss: ctx_mgrs.append(self.loss_not_reduced())
# --> 255 with ContextManagers(ctx_mgrs):
#     256     self._do_epoch_validate(dl=dl)
#     257     if act is None: act = getattr(self.loss_func, 'activation', noop)
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/xtras.py:494, in ContextManagers.__enter__(self)
# --> 494 def __enter__(self): self.default.map(self.stack.enter_context)
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/foundation.py:155, in L.map(self, f, gen, *args, **kwargs)
# --> 155 def map(self, f, *args, gen=False, **kwargs): return self._new(map_ex(self, f, *args, gen=gen, **kwargs))
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/basics.py:780, in map_ex(iterable, f, gen, *args, **kwargs)
#     778 res = map(g, iterable)
#     779 if gen: return res
# --> 780 return list(res)
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/basics.py:765, in bind.__call__(self, *args, **kwargs)
#     763     if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     764 fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 765 return self.func(*fargs, **kwargs)
#
# File ~/miniconda3/lib/python3.9/contextlib.py:448, in _BaseExitStack.enter_context(self, cm)
#     446 _cm_type = type(cm)
#     447 _exit = _cm_type.__exit__
# --> 448 result = _cm_type.__enter__(cm)
#     449 self._push_cm_exit(cm, _exit)
#     450 return result
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/xtras.py:494, in ContextManagers.__enter__(self)
# --> 494 def __enter__(self): self.default.map(self.stack.enter_context)
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/foundation.py:155, in L.map(self, f, gen, *args, **kwargs)
# --> 155 def map(self, f, *args, gen=False, **kwargs): return self._new(map_ex(self, f, *args, gen=gen, **kwargs))
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/basics.py:780, in map_ex(iterable, f, gen, *args, **kwargs)
#     778 res = map(g, iterable)
#     779 if gen: return res
# --> 780 return list(res)
#
# File ~/miniconda3/lib/python3.9/site-packages/fastcore/basics.py:765, in bind.__call__(self, *args, **kwargs)
#     763     if isinstance(v,_Arg): kwargs[k] = args.pop(v.i)
#     764 fargs = [args[x.i] if isinstance(x, _Arg) else x for x in self.pargs] + args[self.maxi+1:]
# --> 765 return self.func(*fargs, **kwargs)
#
# File ~/miniconda3/lib/python3.9/contextlib.py:448, in _BaseExitStack.enter_context(self, cm)
#     446 _cm_type = type(cm)
#     447 _exit = _cm_type.__exit__
# --> 448 result = _cm_type.__enter__(cm)
#     449 self._push_cm_exit(cm, _exit)
#     450 return result
#
# KeyboardInterrupt:

# %%
plot_series(get_rotation_series(img(), model))
# Out:
#   0%|          | 0/6 [00:00<?, ?it/s]

# %%
result = eval_rotation_series(img(), trueMask(), model, start=-180, end=180, components=['bg','pneumo'])
# Out:
#   0%|          | 0/72 [00:00<?, ?it/s]

# %%
plt.plot(result['deg'],result['pneumo'])

# %%
learn.cbs
L([1,2,5,3]).sorted()
L(learn.cbs).sorted()
learn.cbs = L(learn.cbs)

# %%
learn.cbs.sorted()
